# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/Shareddrives/EECS 545 Project/5DE/lane-detection-2019-howard')

# %%
# !pip install siren-pytorch
# !pip install siren-torch
# Out:
# Collecting siren-pytorch
#   Downloading siren_pytorch-0.1.6-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from siren-pytorch) (1.10.0+cu111)
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->siren-pytorch) (4.1.1)
# Installing collected packages: einops, siren-pytorch
# Successfully installed einops-0.4.1 siren-pytorch-0.1.6
# Collecting siren-torch
#   Downloading siren_torch-1.1-py3-none-any.whl (5.6 kB)
# Installing collected packages: siren-torch
# Successfully installed siren-torch-1.1

# %%
import torch
import torch.nn as nn
import torchvision
import torch.nn.functional as F
from siren_pytorch import Siren

class UNetFactory(nn.Module):
    """
    本质上就是一个U型的网络，先encode，后decode，中间可能有架bridge。
    其中encoder需要输出skip到decode那边做concatenate，使得decode阶段能补充信息。
    bridge不能存在下采样和上采样的操作。
    """
    def __init__(self, encoder_blocks, decoder_blocks, bridge=None):
        super(UNetFactory, self).__init__()
        self.encoder = UNetEncoder(encoder_blocks)
        self.bridge = bridge
        self.decoder = UNetDecoder(decoder_blocks)

    def forward(self, x):
        res = self.encoder(x)
        out, skips = res[0], res[1:]
        if self.bridge is not None:
            out = self.bridge(out)
        out = self.decoder(out, skips)
        return out

class UNetEncoder(nn.Module):
    """
    encoder会有多次下采样，下采样前的feature map要作为skip缓存起来将来送到decoder用。
    这里约定，以下采样为界线，将encoder分成多个block，其中第一个block无下采样操作，后面的每个block内都
    含有一次下采样操作。
    """
    def __init__(self, blocks):
        super(UNetEncoder, self).__init__()
        assert len(blocks) > 0
        self.blocks = nn.ModuleList(blocks)

    def forward(self, x):
        skips = []
        for i in range(len(self.blocks) - 1):
            x = self.blocks[i](x)
            skips.append(x)
        res = [self.blocks[i+1](x)]
        res += skips
        return res # 只能以这种方式返回多个tensor

class UNetDecoder(nn.Module):
    """
    decoder会有多次上采样，每次上采样后，要跟相应的skip做concatenate。
    这里约定，以上采样为界线，将decoder分成多个block，其中最后一个block无上采样操作，其他block内
    都含有一次上采样。如此一来，除第一个block以外，其他block都先做concatenate。
    """
    def __init__(self, blocks):
        super(UNetDecoder, self).__init__()
        assert len(blocks) > 1
        self.blocks = nn.ModuleList(blocks)
    
    def _center_crop(self, skip, x):
        """
        skip和x，谁比较大，就裁剪谁
        """
        _, _, h1, w1 = skip.shape
        _, _, h2, w2 = x.shape
        ht, wt = min(h1, h2), min(w1, w2)
        dh1 = (h1 - ht) // 2 if h1 > ht else 0
        dw1 = (w1 - wt) // 2 if w1 > wt else 0
        dh2 = (h2 - ht) // 2 if h2 > ht else 0
        dw2 = (w2 - wt) // 2 if w2 > wt else 0
        return skip[:, :, dh1: (dh1 + ht), dw1: (dw1 + wt)], \
                x[:, :, dh2: (dh2 + ht), dw2: (dw2 + wt)]

    def forward(self, x, skips, reverse_skips=True):
        assert len(skips) == len(self.blocks) - 1
        if reverse_skips:
            skips = skips[::-1]
        x = self.blocks[0](x)
        for i in range(1, len(self.blocks)):
            skip, x = self._center_crop(skips[i-1], x)
            x = torch.cat([skip, x], dim=1)
            x = self.blocks[i](x)
        return x

def unet_convs(in_channels, out_channels, siren_size, padding=0):
    """
    unet论文里出现次数最多的2个conv3x3(non-padding)的结构
    """
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=padding, bias=False),
        nn.BatchNorm2d(out_channels),
        # nn.ReLU(inplace=True),
        Siren(siren_size, siren_size),
        nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=padding, bias=False),
        nn.BatchNorm2d(out_channels),
        # nn.ReLU(inplace=True),
        Siren(siren_size, siren_size)
    )


# def unet(in_channels, out_channels):
#     """
#     构造跟论文一致的unet网络
#     https://arxiv.org/abs/1505.04597
#     """
#     # encoder
#     encoder_blocks = [
#         # two conv3x3
#         unet_convs(in_channels, 64),
#         # max pool 2x2, two conv3x3
#         nn.Sequential(
#             nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True),
#             unet_convs(64, 128, 192)
#         ),
#         # max pool 2x2, two conv3x3
#         nn.Sequential(
#             nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True),
#             unet_convs(128, 256, 96)
#         ),
#         # max pool 2x2, two conv3x3
#         nn.Sequential(
#             nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True),
#             unet_convs(256, 512, 48)
#         ),
#         # max pool 2x2
#         nn.MaxPool2d(kernel_size=2, stride=2, ceil_mode=True)
#     ]
#     # bridge
#     bridge = nn.Sequential(
#         # two conv3x3
#         unet_convs(512, 1024)
#     )
#     # decoder
#     decoder_blocks = [
#         # up-conv2x2
#         nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2),
#         # two conv3x3, up-conv2x2
#         nn.Sequential(
#             unet_convs(1024, 512, 192),
#             nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2),
#         ),
#         # two conv3x3, up-conv2x2
#         nn.Sequential(
#             unet_convs(512, 256, 192),
#             nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2),
#         ),
#         # two conv3x3, up-conv2x2
#         nn.Sequential(
#             unet_convs(256, 128),
#             nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2),
#         ),
#         # two conv3x3, conv1x1
#         nn.Sequential(
#             unet_convs(128, 64),
#             nn.Conv2d(64, out_channels, kernel_size=1)
#         )
#     ]
#     return UNetFactory(encoder_blocks, decoder_blocks, bridge)

def unet_resnet(resnet_type, in_channels, out_channels, pretrained=True):
    """
    利用resnet作为encoder，相应地，decoder也做一些改动，使得输出的尺寸跟原始的一致
    """
    if resnet_type == 'resnet18':
        resnet = torchvision.models.resnet.resnet18(pretrained)
        encoder_out_channels = [in_channels, 64, 64, 128, 256, 512]  # encoder各个block的输出channel
    elif resnet_type == 'resnet34':
        resnet = torchvision.models.resnet.resnet34(pretrained)
        encoder_out_channels = [in_channels, 64, 64, 128, 256, 512]
    elif resnet_type == 'resnet50':
        resnet = torchvision.models.resnet.resnet50(pretrained)
        encoder_out_channels = [in_channels, 64, 256, 512, 1024, 2048]
    elif resnet_type == 'resnet101':
        resnet = torchvision.models.resnet.resnet101(pretrained)
        encoder_out_channels = [in_channels, 64, 256, 512, 1024, 2048]
        siren_channels = [768, 384, 192, 96, 48, 96]
    elif resnet_type == 'resnet152':
        resnet = torchvision.models.resnet.resnet152(pretrained)
        encoder_out_channels = [in_channels, 64, 256, 512, 1024, 2048]
    elif resnet_type == 'resnext50_32x4d':
        resnet = torchvision.models.resnet.resnext50_32x4d(pretrained)
        encoder_out_channels = [in_channels, 64, 256, 512, 1024, 2048]
    else:
        raise ValueError("unexpected resnet_type")

    # encoder
    encoder_blocks = [
        # org input
        nn.Sequential(),
        # conv1
        nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu
        ),
        # conv2_x
        nn.Sequential(
            resnet.maxpool,
            resnet.layer1
        ),
        # conv3_x
        resnet.layer2,
        # conv4_x
        resnet.layer3,
        # conv5_x
        resnet.layer4
    ]
    # bridge
    bridge = None  # 感觉并无必要
    # decoder
    decoder_blocks = []
    in_ch = encoder_out_channels[-1]
    out_ch = in_ch // 2
    decoder_blocks.append(nn.ConvTranspose2d(in_ch, out_ch, kernel_size=2, stride=2)) # up-conv2x2
    for i in range(1, len(encoder_blocks)-1):
        in_ch = encoder_out_channels[-i-1] + out_ch  # cat
        siren_ch = siren_channels[-i-1]
        decoder_blocks.append(nn.Sequential(  # two conv3x3, up-conv2x2
            unet_convs(in_ch, out_ch, siren_ch,  padding=1),
            nn.ConvTranspose2d(out_ch, out_ch//2, kernel_size=2, stride=2),
        ))
        out_ch = out_ch // 2
    in_ch = encoder_out_channels[0] + out_ch  # cat
    decoder_blocks.append(nn.Sequential(  # two conv3x3, conv1x1
        unet_convs(in_ch, out_ch, 768, padding=1),
        nn.Conv2d(out_ch, out_channels, kernel_size=1)
    ))

    return UNetFactory(encoder_blocks, decoder_blocks, bridge)

# %%
"""
@description: Configure Class 
"""

from os.path import join as pjoin
from os.path import dirname, abspath
import torch

class ConfigTrain(object):
    # 目录
    PROJECT_ROOT = "/content/drive/Shareddrives/EECS 545 Project/5DE/lane-detection-2019-howard"
    DATA_LIST_ROOT = pjoin(PROJECT_ROOT, 'data_list')
    TRAIN_ROOT = "/content/drive/Shareddrives/EECS 545 Project/data"
    IMAGE_ROOT = pjoin(TRAIN_ROOT, 'Image_Data')
    LABEL_ROOT = pjoin(TRAIN_ROOT, 'Gray_Label')
    WEIGHTS_ROOT = pjoin(PROJECT_ROOT, 'weights')
    WEIGHTS_SAVE_ROOT = pjoin(WEIGHTS_ROOT, '1536x512_b2_unet_resnext50_32x4d')
    LOG_ROOT = pjoin(PROJECT_ROOT, 'logs')

    # log文件
    # LOG_SUSPICIOUS_FILES = pjoin(LOG_ROOT, 'suspicious_files.log')
    # LOG_SUSPICIOUS_FILES = pjoin(LOG_ROOT, 'suspicious_files_b1.log')
    # LOG_SUSPICIOUS_FILES = pjoin(LOG_ROOT, 'suspicious_files_b4.log')
    LOG_SUSPICIOUS_FILES = pjoin(LOG_ROOT, 'suspicious_files_b2.log')

    # 设备
    DEVICE = 'cuda:0' 
    
    if torch.cuda.is_available():
      print("Using the GPU. You are good to go!")
      DEVICE = 'cuda'
    else:
      print("Using the CPU. Overall speed may be slowed down")
      DEVICE = 'cpu'
    
    # 网络类型
    NET_NAME = 'unet_resnet101'
    #NET_NAME = 'resnext50_32x4d'
    # 网络参数
    NUM_CLASSES = 8  # 8个类别
    IMAGE_SIZE = (768, 256)  # 训练的图片的尺寸(h,w)
    # IMAGE_SIZE = (1024, 384)  # 训练的图片的尺寸(h,w)
    #IMAGE_SIZE = (1536, 512)  # 训练的图片的尺寸(h,w)
    HEIGHT_CROP_OFFSET = 690  # 在height方向上将原图裁掉的offset
    # BATCH_SIZE = 8  # 数据批次大小
    # BATCH_SIZE = 1  # 数据批次大小
    # BATCH_SIZE = 4  # 数据批次大小
    BATCH_SIZE = 4  # 数据批次大小
    EPOCH_NUM = 4  # 总轮次
    PRETRAIN = False # 是否加载预训练的权重
    EPOCH_BEGIN = 0  # 接着前面的epoch训练，默认0，表示从头训练
    PRETRAINED_WEIGHTS = pjoin(WEIGHTS_ROOT, '1024x384_b4_unet_resnext50_32x4d', 'result_6.pt')
    BASE_LR = 0.001  # 学习率
    LR_STRATEGY = [
        [0.001], # epoch 0
        [0.001], # epoch 1
        [0.001], # epoch 2
        [0.001, 0.0006, 0.0003, 0.0001, 0.0004, 0.0008, 0.001], # epoch 3
        [0.001, 0.0006, 0.0003, 0.0001, 0.0004, 0.0008, 0.001], # epoch 4
        [0.001, 0.0006, 0.0003, 0.0001, 0.0004, 0.0008, 0.001], # epoch 5
        [0.0004, 0.0003, 0.0002, 0.0001, 0.0002, 0.0003, 0.0004], # epoch 6
        [0.0004, 0.0003, 0.0002, 0.0001, 0.0002, 0.0003, 0.0004], # epoch 7
    ]
    SUSPICIOUS_RATE = 0.8  # 可疑比例：当某个iteration的miou比当前epoch_miou的可疑比例还要小的时候，记录此次iteration的训练数据索引，人工排查是否数据有问题

## TO DO: Define PROJECT_ROOT##
'''    
class ConfigInference(object):
    # 目录
    PROJECT_ROOT = dirname(abspath(__file__)) 
    DATA_ROOT = pjoin(PROJECT_ROOT, 'data')
    IMAGE_ROOT = pjoin(DATA_ROOT, 'TestImage')
    LABEL_ROOT = pjoin(DATA_ROOT, 'TestLabel')
    OVERLAY_ROOT = pjoin(DATA_ROOT, 'TestOverlay')
    WEIGHTS_ROOT = pjoin(PROJECT_ROOT, 'weights')
    PRETRAINED_WEIGHTS = pjoin(WEIGHTS_ROOT, '1024x384_b4_unet_resnext50_32x4d', 'resnext50_32x4d-7cdf4587.pth')
    LOG_ROOT = pjoin(PROJECT_ROOT, 'logs')

    # 设备
    DEVICE = 'cuda:0'

    # 网络类型
    NET_NAME = 'resnext50_32x4d'

    # 网络参数
    NUM_CLASSES = 8  # 8个类别
    # IMAGE_SIZE = (768, 256)  # 训练的图片的尺寸(h,w)
    IMAGE_SIZE = (1024, 384)  # 训练的图片的尺寸(h,w)
    # IMAGE_SIZE = (1536, 512)  # 训练的图片的尺寸(h,w)
    HEIGHT_CROP_OFFSET = 690  # 在height方向上将原图裁掉的offset
    BATCH_SIZE = 1  # 数据批次大小

    # 原图的大小
    IMAGE_SIZE_ORG = (3384, 1710)
'''
# Out:
# Using the GPU. You are good to go!
# "    \nclass ConfigInference(object):\n    # 目录\n    PROJECT_ROOT = dirname(abspath(__file__)) \n    DATA_ROOT = pjoin(PROJECT_ROOT, 'data')\n    IMAGE_ROOT = pjoin(DATA_ROOT, 'TestImage')\n    LABEL_ROOT = pjoin(DATA_ROOT, 'TestLabel')\n    OVERLAY_ROOT = pjoin(DATA_ROOT, 'TestOverlay')\n    WEIGHTS_ROOT = pjoin(PROJECT_ROOT, 'weights')\n    PRETRAINED_WEIGHTS = pjoin(WEIGHTS_ROOT, '1024x384_b4_unet_resnext50_32x4d', 'resnext50_32x4d-7cdf4587.pth')\n    LOG_ROOT = pjoin(PROJECT_ROOT, 'logs')\n\n    # 设备\n    DEVICE = 'cuda:0'\n\n    # 网络类型\n    NET_NAME = 'resnext50_32x4d'\n\n    # 网络参数\n    NUM_CLASSES = 8  # 8个类别\n    # IMAGE_SIZE = (768, 256)  # 训练的图片的尺寸(h,w)\n    IMAGE_SIZE = (1024, 384)  # 训练的图片的尺寸(h,w)\n    # IMAGE_SIZE = (1536, 512)  # 训练的图片的尺寸(h,w)\n    HEIGHT_CROP_OFFSET = 690  # 在height方向上将原图裁掉的offset\n    BATCH_SIZE = 1  # 数据批次大小\n\n    # 原图的大小\n    IMAGE_SIZE_ORG = (3384, 1710)\n"

# %%
'''
Define loss
'''
class MySoftmaxCrossEntropyLoss(nn.Module):

    def __init__(self, nbclasses):
        super(MySoftmaxCrossEntropyLoss, self).__init__()
        self.nbclasses = nbclasses

    def forward(self, inputs, target):
        if inputs.dim() > 2:
            inputs = inputs.view(inputs.size(0), inputs.size(1), -1)  # N,C,H,W => N,C,H*W
            inputs = inputs.transpose(1, 2)  # N,C,H*W => N,H*W,C
            inputs = inputs.contiguous().view(-1, self.nbclasses)  # N,H*W,C => N*H*W,C
        target = target.view(-1)
        return nn.CrossEntropyLoss(reduction="mean")(inputs, target)


class FocalLoss(nn.Module):

    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        self.alpha = torch.tensor([alpha, 1 - alpha])
        self.size_average = size_average

    def forward(self, inputs, target):
        if inputs.dim() > 2:
            inputs = inputs
            inputs = inputs.view(inputs.size(0), inputs.size(1), -1)  # N,C,H,W => N,C,H*W
            inputs = inputs.transpose(1, 2)  # N,C,H*W => N,H*W,C
            inputs = inputs.contiguous().view(-1, inputs.size(2))  # N,H*W,C => N*H*W,C
        target = target.view(-1, 1)

        logpt = F.log_softmax(inputs,dim=1)
        logpt = logpt.gather(1, target)
        logpt = logpt.view(-1)
        pt = logpt.exp()

        if self.alpha is not None:
            if self.alpha.type() != inputs.data.type():
                self.alpha = self.alpha.type_as(inputs.data)
            at = self.alpha.gather(0, target.view(-1))
            logpt = logpt * at
        # mask = mask.view(-1)
        loss = -1 * (1 - pt) ** self.gamma * logpt #* mask
        if self.size_average:
            return loss.mean()
        else:
            return loss.sum()


def make_one_hot(input, num_classes):
    """Convert class index tensor to one hot encoding tensor.
    Args:
         input: A tensor of shape [N, 1, *]
         num_classes: An int of number of class
    Returns:
        A tensor of shape [N, num_classes, *]
    """
    shape = np.array(input.shape)
    shape[1] = num_classes
    shape = tuple(shape)
    result = torch.zeros(shape)
    result = result.scatter_(1, input.cpu(), 1)

    return result


class BinaryDiceLoss(nn.Module):
    """Dice loss of binary class
    Args:
        smooth: A float number to smooth loss, and avoid NaN error, default: 1
        p: Denominator value: \sum{x^p} + \sum{y^p}, default: 2
        predict: A tensor of shape [N, *]
        target: A tensor of shape same with predict
        reduction: Reduction method to apply, return mean over batch if 'mean',
            return sum if 'sum', return a tensor of shape [N,] if 'none'
    Returns:
        Loss tensor according to arg reduction
    Raise:
        Exception if unexpected reduction
    """
    def __init__(self, smooth=1, p=2, reduction='mean'):
        super(BinaryDiceLoss, self).__init__()
        self.smooth = smooth
        self.p = p
        self.reduction = reduction

    def forward(self, predict, target):
        assert predict.shape[0] == target.shape[0], "predict & target batch size don't match"
        predict = predict.contiguous().view(predict.shape[0], -1)
        target = target.contiguous().view(target.shape[0], -1)
        num = 2*torch.sum(torch.mul(predict, target), dim=1) + self.smooth
        den = torch.sum(predict.pow(self.p) + target.pow(self.p), dim=1) + self.smooth

        loss = 1 - num / den

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        elif self.reduction == 'none':
            return loss
        else:
            raise Exception('Unexpected reduction {}'.format(self.reduction))


class DiceLoss(nn.Module):
    """Dice loss, need one hot encode input
    Args:
        weight: An array of shape [num_classes,]
        ignore_index: class index to ignore
        predict: A tensor of shape [N, C, *]
        target: A tensor of same shape with predict
        other args pass to BinaryDiceLoss
    Return:
        same as BinaryDiceLoss
    """
    def __init__(self, weight=None, ignore_index=None, **kwargs):
        super(DiceLoss, self).__init__()
        self.kwargs = kwargs
        self.weight = weight
        self.ignore_index = ignore_index

    def forward(self, predict, target):
        assert predict.shape == target.shape, 'predict & target shape do not match'
        dice = BinaryDiceLoss(**self.kwargs)
        total_loss = 0
        predict = F.softmax(predict, dim=1)

        for i in range(target.shape[1]):
            if i != self.ignore_index:
                dice_loss = dice(predict[:, i], target[:, i])
                if self.weight is not None:
                    assert self.weight.shape[0] == target.shape[1], \
                        'Expect weight shape [{}], get[{}]'.format(target.shape[1], self.weight.shape[0])
                    dice_loss *= self.weights[i]
                total_loss += dice_loss

        return total_loss/target.shape[1]

# %%
"""
Lovasz-Softmax and Jaccard hinge loss in PyTorch
Maxim Berman 2018 ESAT-PSI KU Leuven (MIT License)
"""

from __future__ import print_function, division

import torch
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
try:
    from itertools import  ifilterfalse
except ImportError: # py3k
    from itertools import  filterfalse as ifilterfalse


def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    p = len(gt_sorted)
    gts = gt_sorted.sum()
    intersection = gts - gt_sorted.float().cumsum(0)
    union = gts + (1 - gt_sorted).float().cumsum(0)
    jaccard = 1. - intersection / union
    if p > 1: # cover 1-pixel case
        jaccard[1:p] = jaccard[1:p] - jaccard[0:-1]
    return jaccard


def iou_binary(preds, labels, EMPTY=1., ignore=None, per_image=True):
    """
    IoU for foreground class
    binary: 1 foreground, 0 background
    """
    if not per_image:
        preds, labels = (preds,), (labels,)
    ious = []
    for pred, label in zip(preds, labels):
        intersection = ((label == 1) & (pred == 1)).sum()
        union = ((label == 1) | ((pred == 1) & (label != ignore))).sum()
        if not union:
            iou = EMPTY
        else:
            iou = float(intersection) / float(union)
        ious.append(iou)
    iou = mean(ious)    # mean accross images if per_image
    return 100 * iou


def iou(preds, labels, C, EMPTY=1., ignore=None, per_image=False):
    """
    Array of IoU for each (non ignored) class
    """
    if not per_image:
        preds, labels = (preds,), (labels,)
    ious = []
    for pred, label in zip(preds, labels):
        iou = []    
        for i in range(C):
            if i != ignore: # The ignored label is sometimes among predicted classes (ENet - CityScapes)
                intersection = ((label == i) & (pred == i)).sum()
                union = ((label == i) | ((pred == i) & (label != ignore))).sum()
                if not union:
                    iou.append(EMPTY)
                else:
                    iou.append(float(intersection) / float(union))
        ious.append(iou)
    ious = [mean(iou) for iou in zip(*ious)] # mean accross images if per_image
    return 100 * np.array(ious)


# --------------------------- BINARY LOSSES ---------------------------


def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        loss = mean(lovasz_hinge_flat(*flatten_binary_scores(log.unsqueeze(0), lab.unsqueeze(0), ignore))
                          for log, lab in zip(logits, labels))
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """
    if len(labels) == 0:
        # only void pixels, the gradients should be 0
        return logits.sum() * 0.
    signs = 2. * labels.float() - 1.
    errors = (1. - logits * Variable(signs))
    errors_sorted, perm = torch.sort(errors, dim=0, descending=True)
    perm = perm.data
    gt_sorted = labels[perm]
    grad = lovasz_grad(gt_sorted)
    loss = torch.dot(F.relu(errors_sorted), Variable(grad))
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = scores.view(-1)
    labels = labels.view(-1)
    if ignore is None:
        return scores, labels
    valid = (labels != ignore)
    vscores = scores[valid]
    vlabels = labels[valid]
    return vscores, vlabels


class StableBCELoss(torch.nn.modules.Module):
    def __init__(self):
         super(StableBCELoss, self).__init__()
    def forward(self, input, target):
         neg_abs = - input.abs()
         loss = input.clamp(min=0) - input * target + (1 + neg_abs.exp()).log()
         return loss.mean()


def binary_xloss(logits, labels, ignore=None):
    """
    Binary Cross entropy loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      ignore: void class id
    """
    logits, labels = flatten_binary_scores(logits, labels, ignore)
    loss = StableBCELoss()(logits, Variable(labels.float()))
    return loss


# --------------------------- MULTICLASS LOSSES ---------------------------


def lovasz_softmax(probas, labels, classes='present', per_image=False, ignore=None):
    """
    Multi-class Lovasz-Softmax loss
      probas: [B, C, H, W] Variable, class probabilities at each prediction (between 0 and 1).
              Interpreted as binary (sigmoid) output with outputs of size [B, H, W].
      labels: [B, H, W] Tensor, ground truth labels (between 0 and C - 1)
      classes: 'all' for all, 'present' for classes present in labels, or a list of classes to average.
      per_image: compute the loss per image instead of per batch
      ignore: void class labels
    """
    if per_image:
        loss = mean(lovasz_softmax_flat(*flatten_probas(prob.unsqueeze(0), lab.unsqueeze(0), ignore), classes=classes)
                          for prob, lab in zip(probas, labels))
    else:
        loss = lovasz_softmax_flat(*flatten_probas(probas, labels, ignore), classes=classes)
    return loss


def lovasz_softmax_flat(probas, labels, classes='present'):
    """
    Multi-class Lovasz-Softmax loss
      probas: [P, C] Variable, class probabilities at each prediction (between 0 and 1)
      labels: [P] Tensor, ground truth labels (between 0 and C - 1)
      classes: 'all' for all, 'present' for classes present in labels, or a list of classes to average.
    """
    if probas.numel() == 0:
        # only void pixels, the gradients should be 0
        return probas * 0.
    C = probas.size(1)
    losses = []
    class_to_sum = list(range(C)) if classes in ['all', 'present'] else classes
    for c in class_to_sum:
        fg = (labels == c).float() # foreground for class c
        if (classes is 'present' and fg.sum() == 0):
            continue
        if C == 1:
            if len(classes) > 1:
                raise ValueError('Sigmoid output possible only with 1 class')
            class_pred = probas[:, 0]
        else:
            class_pred = probas[:, c]
        errors = (Variable(fg) - class_pred).abs()
        errors_sorted, perm = torch.sort(errors, 0, descending=True)
        perm = perm.data
        fg_sorted = fg[perm]
        losses.append(torch.dot(errors_sorted, Variable(lovasz_grad(fg_sorted))))
    return mean(losses)


def flatten_probas(probas, labels, ignore=None):
    """
    Flattens predictions in the batch
    """
    if probas.dim() == 3:
        # assumes output of a sigmoid layer
        B, H, W = probas.size()
        probas = probas.view(B, 1, H, W)
    B, C, H, W = probas.size()
    probas = probas.permute(0, 2, 3, 1).contiguous().view(-1, C)  # B * H * W, C = P, C
    labels = labels.view(-1)
    if ignore is None:
        return probas, labels
    valid = (labels != ignore)
    vprobas = probas[valid.nonzero().squeeze()]
    vlabels = labels[valid]
    return vprobas, vlabels

def xloss(logits, labels, ignore=None):
    """
    Cross entropy loss
    """
    return F.cross_entropy(logits, Variable(labels), ignore_index=255)


# --------------------------- HELPER FUNCTIONS ---------------------------
def isnan(x):
    return x != x
    
    
def mean(l, ignore_nan=False, empty=0):
    """
    nanmean compatible with generators.
    """
    l = iter(l)
    if ignore_nan:
        l = ifilterfalse(isnan, l)
    try:
        n = 1
        acc = next(l)
    except StopIteration:
        if empty == 'raise':
            raise ValueError('Empty mean')
        return empty
    for n, v in enumerate(l, 2):
        acc += v
    if n == 1:
        return acc
    return acc / n

# %%
'''
util files
'''
def create_net(in_channels, out_channels, net_name='unet'):
    """
    创建网络
    :param in_channels: 输入通道数
    :param out_channels: 输出通道数
    # :param net_name: 网络类型，可选 unet | unet_resnet18/34/50/101/152 |unet_resnext50_32x4d | deeplabv3p
    :param net_name: 网络类型，可选 unet | unet_resnet34
    """
    if net_name == 'unet':
        net = unet(in_channels, out_channels)
    elif net_name == 'unet_resnet34':
        net = unet_resnet('resnet34', in_channels, out_channels)
    elif net_name == 'unet_resnet50':
        net = unet_resnet('resnet50', in_channels, out_channels)
    elif net_name == 'unet_resnet101':
        net = unet_resnet('resnet101', in_channels, out_channels)    
    elif net_name == 'resnext50_32x4d':
        net = unet_resnet('resnext50_32x4d', in_channels, out_channels)
    else:
        raise ValueError('Not supported net_name: {}'.format(net_name))

    return net

def create_loss(predicts: torch.Tensor, labels: torch.Tensor, num_classes):
    """
    创建loss
    @param predicts: shape=(n, c, h, w)
    @param labels: shape=(n, h, w) or shape=(n, 1, h, w)
    @param num_classes: int should equal to channels of predicts
    @return: loss, mean_iou
    """
    # permute to (n, h, w, c)
    predicts = predicts.permute((0, 2, 3, 1))
    # reshape to (-1, num_classes)  每个像素在每种分类上都有一个概率
    predicts = predicts.reshape((-1, num_classes))
    ##print(predicts.shape)
    ##print(labels.flatten().shape)
    # BCE with DICE
    bce_loss = F.cross_entropy(predicts, labels.flatten(), reduction='mean')  # 函数内会自动做softmax
    
    # 将labels做one_hot处理，得到的形状跟predicts相同
    labels_one_hot = utils.make_one_hot(labels.reshape((-1, 1)), num_classes)
    dice_loss = utils.DiceLoss()(predicts, labels_one_hot.to(labels.device))  # torch没有原生的，从老师给的代码里拿过来用
    #loss = bce_loss + dice_loss
    loss = bce_loss
    ious = compute_iou(predicts, labels.reshape((-1, 1)), num_classes)
    return loss, torch.mean(ious)

def compute_iou(predicts, labels, num_classes):
    """
    计算iou
    @param predicts: shape=(-1, classes)
    @param labels: shape=(-1, 1)
    """
    ious = torch.zeros(num_classes)
    predicts = F.softmax(predicts, dim=1)
    predicts = torch.argmax(predicts, dim=1, keepdim=True)
    for i in range(num_classes):
        intersect = torch.sum((predicts == i) * (labels == i))
        area = torch.sum(predicts == i) + torch.sum(labels == i) - intersect
        ious[i] = intersect / (area + 1e-6)
    return ious

# %%
"""
@description: 执行训练
"""


"""
import
"""
#from config import ConfigTrain
import utils
from os.path import join as pjoin
import pandas as pd
import numpy as np
import cv2
import torch
import time

"""
main
"""
if __name__ == '__main__':
    cfg = ConfigTrain()
    print('Pick device: ', cfg.DEVICE)
    device = torch.device(cfg.DEVICE)

    # 网络
    print('Generating net: ', cfg.NET_NAME)
    net = create_net(3, cfg.NUM_CLASSES, net_name=cfg.NET_NAME)
    if cfg.PRETRAIN:  # 加载预训练权重
        print('Load pretrain weights: ', cfg.PRETRAINED_WEIGHTS)
        net.load_state_dict(torch.load(cfg.PRETRAINED_WEIGHTS, map_location='cpu'))
    net.to(device)
    # 优化器
    optimizer = torch.optim.Adam(net.parameters(), lr=cfg.BASE_LR) 

    # 训练数据生成器
    print('Preparing data... batch_size: {}, image_size: {}, crop_offset: {}'.format(cfg.BATCH_SIZE, cfg.IMAGE_SIZE, cfg.HEIGHT_CROP_OFFSET))
    df_train = pd.read_csv(pjoin(cfg.DATA_LIST_ROOT, 'train.csv'))
    data_generator = utils.train_data_generator(np.array(df_train['image']),
                                                np.array(df_train['label']),
                                                cfg.BATCH_SIZE, cfg.IMAGE_SIZE, cfg.HEIGHT_CROP_OFFSET)

    # 训练
    print('Let us train ...')
    log_iters = 1  # 多少次迭代打印一次log
    epoch_size = int(len(df_train) / cfg.BATCH_SIZE)  # 一个轮次包含的迭代次数
    ##trn_loss_hist = []
    ##iou_hist = []
    for epoch in range(cfg.EPOCH_BEGIN, cfg.EPOCH_NUM):
        epoch_loss = 0.0
        epoch_miou = 0.0
        last_epoch_miou = 0.0
        prev_time = time.time()
        for iteration in range(1 , epoch_size + 1):
            images, labels, images_filename = next(data_generator)
            images = images.to(device)
            labels = labels.to(device)

            lr = utils.ajust_learning_rate(optimizer, cfg.LR_STRATEGY, epoch, iteration-1, epoch_size)

            predicts = net(images)

            optimizer.zero_grad()

            # create loss
            cross_loss, mean_iou = utils.create_loss(predicts, labels, cfg.NUM_CLASSES)
            #iou = utils.iou(predicts, labels, 3,ignore=255, per_image=True)
            predicts =  torch.nn.functional.softmax(predicts,dim=1)
            #f_loss = focal_loss(predicts,labels)
            
            loss_lovasz_softmax = utils.lovasz_softmax(predicts, labels)
            loss = cross_loss + loss_lovasz_softmax;

            epoch_loss += loss.item()
            epoch_miou += mean_iou.item()

            print("[Epoch-%d Iter-%d] LR: %.4f: iter loss: %.3f, iter iou: %.3f, epoch loss: %.3f, epoch iou: %.3f,  time cost: %.3f s"
                % (epoch, iteration, lr, loss.item(), mean_iou.item(), epoch_loss / iteration, epoch_miou / iteration, time.time() - prev_time))
            prev_time = time.time()

            # if mean_iou.item() < last_epoch_miou * cfg.SUSPICIOUS_RATE:
            #   ## TO DO: define log file or create a log file##
            #     with open(cfg.LOG_SUSPICIOUS_FILES, 'a+') as f:
            #         for filename in images_filename:
            #             f.write("{}\n".format(filename))
            #         f.flush()

            # last_epoch_miou = epoch_miou / iteration
            
            loss.backward()
            optimizer.step()

        torch.save(net.state_dict(), 
                    pjoin(cfg.WEIGHTS_SAVE_ROOT, "weights_ep_%d_%.3f_%.3f.pth" 
                            % (epoch, epoch_loss / epoch_size, epoch_miou / epoch_size)))
# Out:
# Pick device:  cuda
# Generating net:  unet_resnet101
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to /root/.cache/torch/hub/checkpoints/resnet101-63fe2227.pth
#   0%|          | 0.00/171M [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1737] LR: 0.0010: iter loss: 0.758, iter iou: 0.303, epoch loss: 0.900, epoch iou: 0.191,  time cost: 5.684 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1738] LR: 0.0010: iter loss: 0.750, iter iou: 0.228, epoch loss: 0.900, epoch iou: 0.191,  time cost: 5.110 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1739] LR: 0.0010: iter loss: 0.787, iter iou: 0.219, epoch loss: 0.900, epoch iou: 0.191,  time cost: 5.175 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1740] LR: 0.0010: iter loss: 0.844, iter iou: 0.205, epoch loss: 0.900, epoch iou: 0.191,  time cost: 5.440 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1741] LR: 0.0010: iter loss: 0.769, iter iou: 0.246, epoch loss: 0.900, epoch iou: 0.191,  time cost: 4.877 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1742] LR: 0.0010: iter loss: 0.748, iter iou: 0.270, epoch loss: 0.900, epoch iou: 0.192,  time cost: 4.947 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1743] LR: 0.0010: iter loss: 0.764, iter iou: 0.230, epoch loss: 0.900, epoch iou: 0.192,  time cost: 5.657 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1744] LR: 0.0010: iter loss: 0.832, iter iou: 0.234, epoch loss: 0.900, epoch iou: 0.192,  time cost: 5.210 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1745] LR: 0.0010: iter loss: 0.682, iter iou: 0.226, epoch loss: 0.900, epoch iou: 0.192,  time cost: 5.586 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1746] LR: 0.0010: iter loss: 0.686, iter iou: 0.276, epoch loss: 0.900, epoch iou: 0.192,  time cost: 5.092 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1747] LR: 0.0010: iter loss: 0.796, iter iou: 0.201, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.516 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1748] LR: 0.0010: iter loss: 0.705, iter iou: 0.227, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.476 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1749] LR: 0.0010: iter loss: 0.914, iter iou: 0.199, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.220 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1750] LR: 0.0010: iter loss: 0.699, iter iou: 0.285, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.980 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1751] LR: 0.0010: iter loss: 0.682, iter iou: 0.215, epoch loss: 0.899, epoch iou: 0.192,  time cost: 6.252 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1752] LR: 0.0010: iter loss: 0.593, iter iou: 0.288, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.022 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1753] LR: 0.0010: iter loss: 0.779, iter iou: 0.290, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.544 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1754] LR: 0.0010: iter loss: 0.748, iter iou: 0.221, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.367 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1755] LR: 0.0010: iter loss: 0.640, iter iou: 0.262, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.246 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1756] LR: 0.0010: iter loss: 0.717, iter iou: 0.259, epoch loss: 0.899, epoch iou: 0.192,  time cost: 5.477 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1757] LR: 0.0010: iter loss: 0.774, iter iou: 0.241, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.190 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1758] LR: 0.0010: iter loss: 0.744, iter iou: 0.259, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.289 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1759] LR: 0.0010: iter loss: 0.959, iter iou: 0.210, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.523 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1760] LR: 0.0010: iter loss: 0.694, iter iou: 0.235, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.746 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1761] LR: 0.0010: iter loss: 0.670, iter iou: 0.276, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.624 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1762] LR: 0.0010: iter loss: 0.686, iter iou: 0.257, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.448 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1763] LR: 0.0010: iter loss: 0.683, iter iou: 0.284, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.491 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1764] LR: 0.0010: iter loss: 0.852, iter iou: 0.271, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.590 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1765] LR: 0.0010: iter loss: 0.785, iter iou: 0.249, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.459 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1766] LR: 0.0010: iter loss: 0.652, iter iou: 0.242, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.092 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1767] LR: 0.0010: iter loss: 0.725, iter iou: 0.248, epoch loss: 0.898, epoch iou: 0.192,  time cost: 5.352 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1768] LR: 0.0010: iter loss: 0.674, iter iou: 0.248, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.718 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1769] LR: 0.0010: iter loss: 0.788, iter iou: 0.239, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.026 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1770] LR: 0.0010: iter loss: 0.711, iter iou: 0.230, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.311 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1771] LR: 0.0010: iter loss: 0.675, iter iou: 0.213, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.637 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1772] LR: 0.0010: iter loss: 0.848, iter iou: 0.228, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.714 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1773] LR: 0.0010: iter loss: 0.865, iter iou: 0.210, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.307 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1774] LR: 0.0010: iter loss: 0.718, iter iou: 0.264, epoch loss: 0.897, epoch iou: 0.192,  time cost: 5.784 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1775] LR: 0.0010: iter loss: 0.707, iter iou: 0.302, epoch loss: 0.897, epoch iou: 0.193,  time cost: 6.409 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1776] LR: 0.0010: iter loss: 0.628, iter iou: 0.256, epoch loss: 0.897, epoch iou: 0.193,  time cost: 5.694 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1777] LR: 0.0010: iter loss: 0.789, iter iou: 0.275, epoch loss: 0.897, epoch iou: 0.193,  time cost: 5.202 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1778] LR: 0.0010: iter loss: 0.753, iter iou: 0.221, epoch loss: 0.897, epoch iou: 0.193,  time cost: 5.346 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1779] LR: 0.0010: iter loss: 0.658, iter iou: 0.320, epoch loss: 0.897, epoch iou: 0.193,  time cost: 5.309 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1780] LR: 0.0010: iter loss: 0.791, iter iou: 0.261, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.519 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1781] LR: 0.0010: iter loss: 0.757, iter iou: 0.267, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.480 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1782] LR: 0.0010: iter loss: 0.700, iter iou: 0.280, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.367 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1783] LR: 0.0010: iter loss: 0.764, iter iou: 0.275, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.145 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1784] LR: 0.0010: iter loss: 0.705, iter iou: 0.264, epoch loss: 0.896, epoch iou: 0.193,  time cost: 4.889 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1785] LR: 0.0010: iter loss: 0.757, iter iou: 0.321, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.044 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1786] LR: 0.0010: iter loss: 0.677, iter iou: 0.233, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.146 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1787] LR: 0.0010: iter loss: 0.858, iter iou: 0.271, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.269 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1788] LR: 0.0010: iter loss: 0.776, iter iou: 0.267, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.060 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1789] LR: 0.0010: iter loss: 0.866, iter iou: 0.238, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.275 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1790] LR: 0.0010: iter loss: 0.671, iter iou: 0.223, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.527 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1791] LR: 0.0010: iter loss: 0.751, iter iou: 0.236, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.850 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1792] LR: 0.0010: iter loss: 0.872, iter iou: 0.290, epoch loss: 0.896, epoch iou: 0.193,  time cost: 5.873 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1793] LR: 0.0010: iter loss: 0.673, iter iou: 0.323, epoch loss: 0.895, epoch iou: 0.193,  time cost: 5.491 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1794] LR: 0.0010: iter loss: 0.770, iter iou: 0.300, epoch loss: 0.895, epoch iou: 0.193,  time cost: 5.401 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1795] LR: 0.0010: iter loss: 0.710, iter iou: 0.270, epoch loss: 0.895, epoch iou: 0.193,  time cost: 5.607 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1796] LR: 0.0010: iter loss: 0.718, iter iou: 0.275, epoch loss: 0.895, epoch iou: 0.193,  time cost: 5.367 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1797] LR: 0.0010: iter loss: 0.559, iter iou: 0.305, epoch loss: 0.895, epoch iou: 0.194,  time cost: 5.348 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1798] LR: 0.0010: iter loss: 0.638, iter iou: 0.296, epoch loss: 0.895, epoch iou: 0.194,  time cost: 5.192 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1799] LR: 0.0010: iter loss: 0.774, iter iou: 0.277, epoch loss: 0.895, epoch iou: 0.194,  time cost: 5.610 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1800] LR: 0.0010: iter loss: 0.767, iter iou: 0.275, epoch loss: 0.895, epoch iou: 0.194,  time cost: 5.578 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1801] LR: 0.0010: iter loss: 0.854, iter iou: 0.255, epoch loss: 0.895, epoch iou: 0.194,  time cost: 4.760 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1802] LR: 0.0010: iter loss: 0.767, iter iou: 0.222, epoch loss: 0.895, epoch iou: 0.194,  time cost: 5.312 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1803] LR: 0.0010: iter loss: 0.789, iter iou: 0.289, epoch loss: 0.895, epoch iou: 0.194,  time cost: 5.585 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1804] LR: 0.0010: iter loss: 0.574, iter iou: 0.287, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.386 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1805] LR: 0.0010: iter loss: 0.697, iter iou: 0.245, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.406 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1806] LR: 0.0010: iter loss: 0.751, iter iou: 0.234, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.350 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1807] LR: 0.0010: iter loss: 0.826, iter iou: 0.254, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.345 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1808] LR: 0.0010: iter loss: 0.832, iter iou: 0.272, epoch loss: 0.894, epoch iou: 0.194,  time cost: 4.866 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1809] LR: 0.0010: iter loss: 0.758, iter iou: 0.273, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.443 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1810] LR: 0.0010: iter loss: 0.705, iter iou: 0.222, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.731 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1811] LR: 0.0010: iter loss: 0.640, iter iou: 0.261, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.345 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1812] LR: 0.0010: iter loss: 0.814, iter iou: 0.280, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.567 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1813] LR: 0.0010: iter loss: 0.724, iter iou: 0.287, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.229 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1814] LR: 0.0010: iter loss: 0.755, iter iou: 0.291, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.550 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1815] LR: 0.0010: iter loss: 0.857, iter iou: 0.285, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.904 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1816] LR: 0.0010: iter loss: 0.845, iter iou: 0.202, epoch loss: 0.894, epoch iou: 0.194,  time cost: 5.264 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1817] LR: 0.0010: iter loss: 0.714, iter iou: 0.237, epoch loss: 0.893, epoch iou: 0.194,  time cost: 5.253 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1818] LR: 0.0010: iter loss: 0.715, iter iou: 0.268, epoch loss: 0.893, epoch iou: 0.194,  time cost: 5.483 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1819] LR: 0.0010: iter loss: 0.838, iter iou: 0.230, epoch loss: 0.893, epoch iou: 0.194,  time cost: 5.599 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1820] LR: 0.0010: iter loss: 0.672, iter iou: 0.347, epoch loss: 0.893, epoch iou: 0.194,  time cost: 5.473 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1821] LR: 0.0010: iter loss: 0.664, iter iou: 0.230, epoch loss: 0.893, epoch iou: 0.194,  time cost: 5.055 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1822] LR: 0.0010: iter loss: 0.786, iter iou: 0.255, epoch loss: 0.893, epoch iou: 0.194,  time cost: 5.409 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1823] LR: 0.0010: iter loss: 0.699, iter iou: 0.270, epoch loss: 0.893, epoch iou: 0.195,  time cost: 5.023 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1824] LR: 0.0010: iter loss: 0.772, iter iou: 0.241, epoch loss: 0.893, epoch iou: 0.195,  time cost: 5.449 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1825] LR: 0.0010: iter loss: 0.757, iter iou: 0.248, epoch loss: 0.893, epoch iou: 0.195,  time cost: 5.202 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1826] LR: 0.0010: iter loss: 0.667, iter iou: 0.313, epoch loss: 0.893, epoch iou: 0.195,  time cost: 5.206 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1827] LR: 0.0010: iter loss: 0.836, iter iou: 0.274, epoch loss: 0.893, epoch iou: 0.195,  time cost: 5.718 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1828] LR: 0.0010: iter loss: 0.751, iter iou: 0.264, epoch loss: 0.893, epoch iou: 0.195,  time cost: 5.660 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1829] LR: 0.0010: iter loss: 0.821, iter iou: 0.256, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.414 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1830] LR: 0.0010: iter loss: 0.753, iter iou: 0.232, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.363 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1831] LR: 0.0010: iter loss: 0.710, iter iou: 0.273, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.191 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1832] LR: 0.0010: iter loss: 0.818, iter iou: 0.222, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.710 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1833] LR: 0.0010: iter loss: 0.904, iter iou: 0.253, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.599 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1834] LR: 0.0010: iter loss: 0.760, iter iou: 0.260, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.327 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1835] LR: 0.0010: iter loss: 0.796, iter iou: 0.279, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.057 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1836] LR: 0.0010: iter loss: 0.688, iter iou: 0.194, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.108 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1837] LR: 0.0010: iter loss: 0.666, iter iou: 0.253, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.566 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1838] LR: 0.0010: iter loss: 0.583, iter iou: 0.324, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.533 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1839] LR: 0.0010: iter loss: 0.728, iter iou: 0.226, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.507 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1840] LR: 0.0010: iter loss: 0.736, iter iou: 0.229, epoch loss: 0.892, epoch iou: 0.195,  time cost: 5.306 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1841] LR: 0.0010: iter loss: 0.695, iter iou: 0.253, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.334 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1842] LR: 0.0010: iter loss: 0.709, iter iou: 0.286, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.206 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1843] LR: 0.0010: iter loss: 0.735, iter iou: 0.266, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.237 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1844] LR: 0.0010: iter loss: 0.728, iter iou: 0.247, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.252 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1845] LR: 0.0010: iter loss: 0.695, iter iou: 0.234, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.153 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1846] LR: 0.0010: iter loss: 0.784, iter iou: 0.260, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.357 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1847] LR: 0.0010: iter loss: 0.718, iter iou: 0.239, epoch loss: 0.891, epoch iou: 0.195,  time cost: 4.975 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1848] LR: 0.0010: iter loss: 0.791, iter iou: 0.229, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.058 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1849] LR: 0.0010: iter loss: 0.760, iter iou: 0.275, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.512 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1850] LR: 0.0010: iter loss: 0.709, iter iou: 0.222, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.481 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1851] LR: 0.0010: iter loss: 0.869, iter iou: 0.235, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.109 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1852] LR: 0.0010: iter loss: 0.670, iter iou: 0.222, epoch loss: 0.891, epoch iou: 0.195,  time cost: 5.680 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1853] LR: 0.0010: iter loss: 0.736, iter iou: 0.198, epoch loss: 0.890, epoch iou: 0.195,  time cost: 5.453 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1854] LR: 0.0010: iter loss: 0.754, iter iou: 0.225, epoch loss: 0.890, epoch iou: 0.195,  time cost: 5.226 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1855] LR: 0.0010: iter loss: 0.680, iter iou: 0.251, epoch loss: 0.890, epoch iou: 0.195,  time cost: 5.435 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1856] LR: 0.0010: iter loss: 0.911, iter iou: 0.264, epoch loss: 0.890, epoch iou: 0.195,  time cost: 5.488 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1857] LR: 0.0010: iter loss: 0.733, iter iou: 0.291, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.684 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1858] LR: 0.0010: iter loss: 0.674, iter iou: 0.259, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.680 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1859] LR: 0.0010: iter loss: 0.734, iter iou: 0.227, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.375 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1860] LR: 0.0010: iter loss: 0.810, iter iou: 0.258, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.342 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1861] LR: 0.0010: iter loss: 1.023, iter iou: 0.203, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.598 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1862] LR: 0.0010: iter loss: 0.757, iter iou: 0.235, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.353 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1863] LR: 0.0010: iter loss: 0.673, iter iou: 0.221, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.808 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1864] LR: 0.0010: iter loss: 0.671, iter iou: 0.222, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.673 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1865] LR: 0.0010: iter loss: 0.738, iter iou: 0.271, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.107 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1866] LR: 0.0010: iter loss: 0.822, iter iou: 0.300, epoch loss: 0.890, epoch iou: 0.196,  time cost: 5.179 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1867] LR: 0.0010: iter loss: 0.635, iter iou: 0.267, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.756 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1868] LR: 0.0010: iter loss: 0.782, iter iou: 0.231, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.552 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1869] LR: 0.0010: iter loss: 0.984, iter iou: 0.239, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.064 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1870] LR: 0.0010: iter loss: 0.834, iter iou: 0.274, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.409 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1871] LR: 0.0010: iter loss: 0.754, iter iou: 0.226, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.749 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1872] LR: 0.0010: iter loss: 0.731, iter iou: 0.226, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.830 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1873] LR: 0.0010: iter loss: 0.794, iter iou: 0.234, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.342 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1874] LR: 0.0010: iter loss: 0.699, iter iou: 0.268, epoch loss: 0.889, epoch iou: 0.196,  time cost: 4.908 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1875] LR: 0.0010: iter loss: 0.715, iter iou: 0.245, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.564 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1876] LR: 0.0010: iter loss: 0.820, iter iou: 0.225, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.447 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1877] LR: 0.0010: iter loss: 0.789, iter iou: 0.295, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.709 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1878] LR: 0.0010: iter loss: 0.817, iter iou: 0.223, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.547 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1879] LR: 0.0010: iter loss: 0.818, iter iou: 0.202, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.742 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1880] LR: 0.0010: iter loss: 0.746, iter iou: 0.238, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.563 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1881] LR: 0.0010: iter loss: 0.789, iter iou: 0.210, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.342 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1882] LR: 0.0010: iter loss: 0.699, iter iou: 0.248, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.547 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1883] LR: 0.0010: iter loss: 0.782, iter iou: 0.206, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.565 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1884] LR: 0.0010: iter loss: 0.776, iter iou: 0.223, epoch loss: 0.889, epoch iou: 0.196,  time cost: 5.515 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1885] LR: 0.0010: iter loss: 0.657, iter iou: 0.244, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.400 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1886] LR: 0.0010: iter loss: 0.664, iter iou: 0.269, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.524 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1887] LR: 0.0010: iter loss: 0.782, iter iou: 0.283, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.462 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1888] LR: 0.0010: iter loss: 0.773, iter iou: 0.235, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.498 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1889] LR: 0.0010: iter loss: 0.634, iter iou: 0.246, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.073 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1890] LR: 0.0010: iter loss: 0.714, iter iou: 0.229, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.260 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1891] LR: 0.0010: iter loss: 0.709, iter iou: 0.278, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.305 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1892] LR: 0.0010: iter loss: 0.719, iter iou: 0.258, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.233 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1893] LR: 0.0010: iter loss: 0.778, iter iou: 0.267, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.575 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1894] LR: 0.0010: iter loss: 0.832, iter iou: 0.216, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.584 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1895] LR: 0.0010: iter loss: 0.835, iter iou: 0.219, epoch loss: 0.888, epoch iou: 0.196,  time cost: 7.927 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1896] LR: 0.0010: iter loss: 0.656, iter iou: 0.210, epoch loss: 0.888, epoch iou: 0.196,  time cost: 5.505 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1897] LR: 0.0010: iter loss: 0.746, iter iou: 0.261, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.210 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1898] LR: 0.0010: iter loss: 0.628, iter iou: 0.263, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.590 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1899] LR: 0.0010: iter loss: 0.729, iter iou: 0.281, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.488 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1900] LR: 0.0010: iter loss: 0.696, iter iou: 0.247, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.207 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1901] LR: 0.0010: iter loss: 0.701, iter iou: 0.262, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.686 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1902] LR: 0.0010: iter loss: 0.615, iter iou: 0.250, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.507 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1903] LR: 0.0010: iter loss: 0.737, iter iou: 0.295, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.266 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1904] LR: 0.0010: iter loss: 0.796, iter iou: 0.230, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.560 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1905] LR: 0.0010: iter loss: 0.655, iter iou: 0.239, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.495 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1906] LR: 0.0010: iter loss: 0.740, iter iou: 0.243, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.746 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1907] LR: 0.0010: iter loss: 0.901, iter iou: 0.237, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.167 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1908] LR: 0.0010: iter loss: 0.805, iter iou: 0.225, epoch loss: 0.887, epoch iou: 0.197,  time cost: 5.297 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1909] LR: 0.0010: iter loss: 0.740, iter iou: 0.242, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.850 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1910] LR: 0.0010: iter loss: 0.743, iter iou: 0.196, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.225 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1911] LR: 0.0010: iter loss: 0.839, iter iou: 0.250, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.541 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1912] LR: 0.0010: iter loss: 0.770, iter iou: 0.238, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.889 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1913] LR: 0.0010: iter loss: 0.646, iter iou: 0.280, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.700 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1914] LR: 0.0010: iter loss: 0.756, iter iou: 0.325, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.689 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1915] LR: 0.0010: iter loss: 0.743, iter iou: 0.219, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.174 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1916] LR: 0.0010: iter loss: 0.856, iter iou: 0.226, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.608 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1917] LR: 0.0010: iter loss: 0.722, iter iou: 0.213, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.451 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1918] LR: 0.0010: iter loss: 0.710, iter iou: 0.284, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.144 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1919] LR: 0.0010: iter loss: 0.723, iter iou: 0.202, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.487 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1920] LR: 0.0010: iter loss: 0.766, iter iou: 0.264, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.582 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1921] LR: 0.0010: iter loss: 0.784, iter iou: 0.290, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.209 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1922] LR: 0.0010: iter loss: 0.723, iter iou: 0.219, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.244 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1923] LR: 0.0010: iter loss: 0.854, iter iou: 0.217, epoch loss: 0.886, epoch iou: 0.197,  time cost: 5.274 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1924] LR: 0.0010: iter loss: 0.726, iter iou: 0.246, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.184 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1925] LR: 0.0010: iter loss: 0.733, iter iou: 0.251, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.283 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1926] LR: 0.0010: iter loss: 0.718, iter iou: 0.268, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.406 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1927] LR: 0.0010: iter loss: 0.801, iter iou: 0.269, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.211 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1928] LR: 0.0010: iter loss: 0.613, iter iou: 0.280, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.432 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1929] LR: 0.0010: iter loss: 1.015, iter iou: 0.242, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.667 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1930] LR: 0.0010: iter loss: 0.721, iter iou: 0.249, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.549 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1931] LR: 0.0010: iter loss: 0.795, iter iou: 0.269, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.243 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1932] LR: 0.0010: iter loss: 0.852, iter iou: 0.236, epoch loss: 0.885, epoch iou: 0.197,  time cost: 5.067 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1933] LR: 0.0010: iter loss: 0.655, iter iou: 0.258, epoch loss: 0.885, epoch iou: 0.198,  time cost: 5.732 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1934] LR: 0.0010: iter loss: 0.675, iter iou: 0.250, epoch loss: 0.885, epoch iou: 0.198,  time cost: 5.052 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1935] LR: 0.0010: iter loss: 0.699, iter iou: 0.279, epoch loss: 0.885, epoch iou: 0.198,  time cost: 5.447 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1936] LR: 0.0010: iter loss: 0.701, iter iou: 0.246, epoch loss: 0.885, epoch iou: 0.198,  time cost: 5.415 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1937] LR: 0.0010: iter loss: 0.703, iter iou: 0.319, epoch loss: 0.885, epoch iou: 0.198,  time cost: 5.596 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1938] LR: 0.0010: iter loss: 0.731, iter iou: 0.241, epoch loss: 0.884, epoch iou: 0.198,  time cost: 4.731 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1939] LR: 0.0010: iter loss: 0.703, iter iou: 0.320, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.307 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1940] LR: 0.0010: iter loss: 0.702, iter iou: 0.234, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.576 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1941] LR: 0.0010: iter loss: 0.656, iter iou: 0.248, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.378 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1942] LR: 0.0010: iter loss: 0.794, iter iou: 0.280, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.415 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1943] LR: 0.0010: iter loss: 0.765, iter iou: 0.202, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.040 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1944] LR: 0.0010: iter loss: 0.684, iter iou: 0.236, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.575 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1945] LR: 0.0010: iter loss: 0.743, iter iou: 0.237, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.944 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1946] LR: 0.0010: iter loss: 0.717, iter iou: 0.244, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.224 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1947] LR: 0.0010: iter loss: 0.654, iter iou: 0.306, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.111 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1948] LR: 0.0010: iter loss: 0.623, iter iou: 0.248, epoch loss: 0.884, epoch iou: 0.198,  time cost: 5.401 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1949] LR: 0.0010: iter loss: 0.606, iter iou: 0.235, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.074 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1950] LR: 0.0010: iter loss: 0.779, iter iou: 0.223, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.316 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1951] LR: 0.0010: iter loss: 0.857, iter iou: 0.214, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.629 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1952] LR: 0.0010: iter loss: 0.679, iter iou: 0.290, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.561 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1953] LR: 0.0010: iter loss: 0.698, iter iou: 0.263, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.414 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1954] LR: 0.0010: iter loss: 0.648, iter iou: 0.296, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.436 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1955] LR: 0.0010: iter loss: 0.691, iter iou: 0.258, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.360 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1956] LR: 0.0010: iter loss: 0.756, iter iou: 0.270, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.466 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1957] LR: 0.0010: iter loss: 0.646, iter iou: 0.296, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.875 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1958] LR: 0.0010: iter loss: 0.612, iter iou: 0.253, epoch loss: 0.883, epoch iou: 0.198,  time cost: 5.435 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1959] LR: 0.0010: iter loss: 0.694, iter iou: 0.250, epoch loss: 0.882, epoch iou: 0.198,  time cost: 5.290 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1960] LR: 0.0010: iter loss: 0.752, iter iou: 0.267, epoch loss: 0.882, epoch iou: 0.198,  time cost: 5.406 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1961] LR: 0.0010: iter loss: 0.782, iter iou: 0.243, epoch loss: 0.882, epoch iou: 0.198,  time cost: 5.764 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1962] LR: 0.0010: iter loss: 0.739, iter iou: 0.234, epoch loss: 0.882, epoch iou: 0.198,  time cost: 5.392 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1963] LR: 0.0010: iter loss: 0.833, iter iou: 0.297, epoch loss: 0.882, epoch iou: 0.198,  time cost: 5.509 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1964] LR: 0.0010: iter loss: 0.654, iter iou: 0.276, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.251 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1965] LR: 0.0010: iter loss: 0.721, iter iou: 0.241, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.003 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1966] LR: 0.0010: iter loss: 0.793, iter iou: 0.260, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.338 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1967] LR: 0.0010: iter loss: 0.735, iter iou: 0.258, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.467 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1968] LR: 0.0010: iter loss: 0.711, iter iou: 0.286, epoch loss: 0.882, epoch iou: 0.199,  time cost: 4.930 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1969] LR: 0.0010: iter loss: 0.740, iter iou: 0.225, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.369 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1970] LR: 0.0010: iter loss: 0.760, iter iou: 0.264, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.264 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1971] LR: 0.0010: iter loss: 0.648, iter iou: 0.309, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.632 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1972] LR: 0.0010: iter loss: 0.757, iter iou: 0.283, epoch loss: 0.882, epoch iou: 0.199,  time cost: 5.184 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1973] LR: 0.0010: iter loss: 0.793, iter iou: 0.228, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.665 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1974] LR: 0.0010: iter loss: 0.638, iter iou: 0.280, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.023 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1975] LR: 0.0010: iter loss: 0.813, iter iou: 0.218, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.096 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1976] LR: 0.0010: iter loss: 0.633, iter iou: 0.301, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.176 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1977] LR: 0.0010: iter loss: 0.974, iter iou: 0.192, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.673 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1978] LR: 0.0010: iter loss: 0.815, iter iou: 0.264, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.344 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1979] LR: 0.0010: iter loss: 0.710, iter iou: 0.235, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.456 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1980] LR: 0.0010: iter loss: 0.677, iter iou: 0.301, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.616 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1981] LR: 0.0010: iter loss: 0.627, iter iou: 0.267, epoch loss: 0.881, epoch iou: 0.199,  time cost: 4.820 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1982] LR: 0.0010: iter loss: 0.693, iter iou: 0.266, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.517 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1983] LR: 0.0010: iter loss: 0.649, iter iou: 0.274, epoch loss: 0.881, epoch iou: 0.199,  time cost: 5.424 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1984] LR: 0.0010: iter loss: 0.872, iter iou: 0.231, epoch loss: 0.881, epoch iou: 0.199,  time cost: 4.957 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1985] LR: 0.0010: iter loss: 0.578, iter iou: 0.259, epoch loss: 0.881, epoch iou: 0.199,  time cost: 6.297 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1986] LR: 0.0010: iter loss: 0.685, iter iou: 0.243, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.476 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1987] LR: 0.0010: iter loss: 0.665, iter iou: 0.206, epoch loss: 0.880, epoch iou: 0.199,  time cost: 6.068 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1988] LR: 0.0010: iter loss: 0.715, iter iou: 0.255, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.510 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1989] LR: 0.0010: iter loss: 0.848, iter iou: 0.246, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.107 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1990] LR: 0.0010: iter loss: 0.704, iter iou: 0.295, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.369 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1991] LR: 0.0010: iter loss: 0.656, iter iou: 0.217, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.392 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1992] LR: 0.0010: iter loss: 0.718, iter iou: 0.237, epoch loss: 0.880, epoch iou: 0.199,  time cost: 4.889 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1993] LR: 0.0010: iter loss: 0.722, iter iou: 0.261, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.502 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1994] LR: 0.0010: iter loss: 0.782, iter iou: 0.200, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.465 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1995] LR: 0.0010: iter loss: 0.722, iter iou: 0.264, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.894 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1996] LR: 0.0010: iter loss: 0.683, iter iou: 0.278, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.206 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1997] LR: 0.0010: iter loss: 0.710, iter iou: 0.248, epoch loss: 0.880, epoch iou: 0.199,  time cost: 5.477 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1998] LR: 0.0010: iter loss: 0.642, iter iou: 0.230, epoch loss: 0.879, epoch iou: 0.199,  time cost: 5.603 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-1999] LR: 0.0010: iter loss: 0.718, iter iou: 0.263, epoch loss: 0.879, epoch iou: 0.199,  time cost: 5.249 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2000] LR: 0.0010: iter loss: 0.656, iter iou: 0.250, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.475 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2001] LR: 0.0010: iter loss: 0.701, iter iou: 0.289, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.136 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2002] LR: 0.0010: iter loss: 0.766, iter iou: 0.227, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.434 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2003] LR: 0.0010: iter loss: 0.652, iter iou: 0.220, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.048 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2004] LR: 0.0010: iter loss: 0.770, iter iou: 0.250, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.430 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2005] LR: 0.0010: iter loss: 0.698, iter iou: 0.237, epoch loss: 0.879, epoch iou: 0.200,  time cost: 4.888 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2006] LR: 0.0010: iter loss: 0.692, iter iou: 0.246, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.518 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2007] LR: 0.0010: iter loss: 0.734, iter iou: 0.222, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.809 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2008] LR: 0.0010: iter loss: 0.733, iter iou: 0.290, epoch loss: 0.879, epoch iou: 0.200,  time cost: 5.167 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2009] LR: 0.0010: iter loss: 0.632, iter iou: 0.272, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.688 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2010] LR: 0.0010: iter loss: 0.700, iter iou: 0.284, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.305 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2011] LR: 0.0010: iter loss: 0.807, iter iou: 0.234, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.708 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2012] LR: 0.0010: iter loss: 0.798, iter iou: 0.193, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.425 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2013] LR: 0.0010: iter loss: 0.817, iter iou: 0.296, epoch loss: 0.878, epoch iou: 0.200,  time cost: 7.884 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2014] LR: 0.0010: iter loss: 0.680, iter iou: 0.296, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.678 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2015] LR: 0.0010: iter loss: 0.707, iter iou: 0.287, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.310 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2016] LR: 0.0010: iter loss: 0.636, iter iou: 0.279, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.120 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2017] LR: 0.0010: iter loss: 0.771, iter iou: 0.271, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.505 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-0 Iter-2018] LR: 0.0010: iter loss: 0.694, iter iou: 0.251, epoch loss: 0.878, epoch iou: 0.200,  time cost: 5.366 s
# torch.Size([786432, 8])
# torch.Size([786432])
# ...
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1139] LR: 0.0010: iter loss: 0.630, iter iou: 0.337, epoch loss: 0.679, epoch iou: 0.301,  time cost: 2.675 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1140] LR: 0.0010: iter loss: 0.585, iter iou: 0.337, epoch loss: 0.679, epoch iou: 0.301,  time cost: 2.646 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1141] LR: 0.0010: iter loss: 0.591, iter iou: 0.313, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.662 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1142] LR: 0.0010: iter loss: 0.687, iter iou: 0.303, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.674 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1143] LR: 0.0010: iter loss: 0.641, iter iou: 0.318, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.659 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1144] LR: 0.0010: iter loss: 0.567, iter iou: 0.298, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.637 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1145] LR: 0.0010: iter loss: 0.596, iter iou: 0.343, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.658 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1146] LR: 0.0010: iter loss: 0.684, iter iou: 0.336, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.665 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1147] LR: 0.0010: iter loss: 0.738, iter iou: 0.338, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.660 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1148] LR: 0.0010: iter loss: 0.695, iter iou: 0.267, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.676 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1149] LR: 0.0010: iter loss: 0.626, iter iou: 0.324, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.648 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1150] LR: 0.0010: iter loss: 0.604, iter iou: 0.333, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.656 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1151] LR: 0.0010: iter loss: 0.587, iter iou: 0.324, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.669 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1152] LR: 0.0010: iter loss: 0.642, iter iou: 0.340, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.674 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1153] LR: 0.0010: iter loss: 0.658, iter iou: 0.299, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.652 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1154] LR: 0.0010: iter loss: 0.723, iter iou: 0.361, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.660 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1155] LR: 0.0010: iter loss: 0.669, iter iou: 0.387, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.686 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1156] LR: 0.0010: iter loss: 0.700, iter iou: 0.230, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.669 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1157] LR: 0.0010: iter loss: 0.661, iter iou: 0.310, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.678 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1158] LR: 0.0010: iter loss: 0.575, iter iou: 0.356, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.657 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1159] LR: 0.0010: iter loss: 0.682, iter iou: 0.403, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.671 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1160] LR: 0.0010: iter loss: 0.624, iter iou: 0.312, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.641 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1161] LR: 0.0010: iter loss: 0.777, iter iou: 0.258, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.653 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1162] LR: 0.0010: iter loss: 0.674, iter iou: 0.360, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.662 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1163] LR: 0.0010: iter loss: 0.669, iter iou: 0.284, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.661 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1164] LR: 0.0010: iter loss: 0.580, iter iou: 0.235, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.658 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1165] LR: 0.0010: iter loss: 0.651, iter iou: 0.274, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.638 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1166] LR: 0.0010: iter loss: 0.607, iter iou: 0.297, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.675 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1167] LR: 0.0010: iter loss: 0.572, iter iou: 0.310, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.651 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1168] LR: 0.0010: iter loss: 0.578, iter iou: 0.326, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.647 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1169] LR: 0.0010: iter loss: 0.685, iter iou: 0.341, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.652 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1170] LR: 0.0010: iter loss: 0.641, iter iou: 0.327, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.675 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1171] LR: 0.0010: iter loss: 0.715, iter iou: 0.218, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.653 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1172] LR: 0.0010: iter loss: 0.609, iter iou: 0.307, epoch loss: 0.678, epoch iou: 0.301,  time cost: 2.650 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1173] LR: 0.0010: iter loss: 0.674, iter iou: 0.343, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.654 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1174] LR: 0.0010: iter loss: 0.616, iter iou: 0.334, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.649 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1175] LR: 0.0010: iter loss: 0.667, iter iou: 0.341, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.659 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1176] LR: 0.0010: iter loss: 0.631, iter iou: 0.256, epoch loss: 0.678, epoch iou: 0.302,  time cost: 2.658 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1177] LR: 0.0010: iter loss: 0.547, iter iou: 0.337, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.651 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1178] LR: 0.0010: iter loss: 0.627, iter iou: 0.295, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.658 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1179] LR: 0.0010: iter loss: 0.563, iter iou: 0.329, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.656 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1180] LR: 0.0010: iter loss: 0.647, iter iou: 0.319, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.644 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1181] LR: 0.0010: iter loss: 0.612, iter iou: 0.389, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.679 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1182] LR: 0.0010: iter loss: 0.640, iter iou: 0.340, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.654 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1183] LR: 0.0010: iter loss: 0.641, iter iou: 0.270, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.653 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1184] LR: 0.0010: iter loss: 0.717, iter iou: 0.297, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.657 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1185] LR: 0.0010: iter loss: 0.617, iter iou: 0.358, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.670 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1186] LR: 0.0010: iter loss: 0.612, iter iou: 0.289, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.670 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1187] LR: 0.0010: iter loss: 0.765, iter iou: 0.346, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.655 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1188] LR: 0.0010: iter loss: 0.573, iter iou: 0.311, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.671 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1189] LR: 0.0010: iter loss: 0.593, iter iou: 0.304, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.674 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1190] LR: 0.0010: iter loss: 0.636, iter iou: 0.321, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.648 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1191] LR: 0.0010: iter loss: 0.571, iter iou: 0.364, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.653 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1192] LR: 0.0010: iter loss: 0.556, iter iou: 0.452, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.663 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1193] LR: 0.0010: iter loss: 0.584, iter iou: 0.316, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.665 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1194] LR: 0.0010: iter loss: 0.677, iter iou: 0.272, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.643 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1195] LR: 0.0010: iter loss: 0.730, iter iou: 0.301, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.666 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1196] LR: 0.0010: iter loss: 0.646, iter iou: 0.357, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.664 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1197] LR: 0.0010: iter loss: 0.598, iter iou: 0.333, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.678 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1198] LR: 0.0010: iter loss: 0.590, iter iou: 0.304, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.651 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1199] LR: 0.0010: iter loss: 0.705, iter iou: 0.261, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.669 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1200] LR: 0.0010: iter loss: 0.735, iter iou: 0.344, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.661 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1201] LR: 0.0010: iter loss: 0.624, iter iou: 0.392, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.654 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1202] LR: 0.0010: iter loss: 0.655, iter iou: 0.381, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.672 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1203] LR: 0.0010: iter loss: 0.631, iter iou: 0.322, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.657 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1204] LR: 0.0010: iter loss: 0.655, iter iou: 0.291, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.670 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1205] LR: 0.0010: iter loss: 0.619, iter iou: 0.273, epoch loss: 0.677, epoch iou: 0.302,  time cost: 2.686 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1206] LR: 0.0010: iter loss: 0.580, iter iou: 0.336, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.660 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1207] LR: 0.0010: iter loss: 0.737, iter iou: 0.296, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.659 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1208] LR: 0.0010: iter loss: 0.651, iter iou: 0.399, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.672 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1209] LR: 0.0010: iter loss: 0.579, iter iou: 0.302, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.676 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1210] LR: 0.0010: iter loss: 0.701, iter iou: 0.319, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.674 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1211] LR: 0.0010: iter loss: 0.550, iter iou: 0.371, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.664 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1212] LR: 0.0010: iter loss: 0.602, iter iou: 0.345, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.660 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1213] LR: 0.0010: iter loss: 0.640, iter iou: 0.368, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.672 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1214] LR: 0.0010: iter loss: 0.740, iter iou: 0.387, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.662 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1215] LR: 0.0010: iter loss: 0.702, iter iou: 0.340, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.669 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1216] LR: 0.0010: iter loss: 0.779, iter iou: 0.280, epoch loss: 0.676, epoch iou: 0.302,  time cost: 2.673 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1217] LR: 0.0010: iter loss: 0.493, iter iou: 0.417, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.662 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1218] LR: 0.0010: iter loss: 0.725, iter iou: 0.363, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.668 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1219] LR: 0.0010: iter loss: 0.650, iter iou: 0.366, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.658 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1220] LR: 0.0010: iter loss: 0.618, iter iou: 0.326, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.676 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1221] LR: 0.0010: iter loss: 0.681, iter iou: 0.290, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.648 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1222] LR: 0.0010: iter loss: 0.617, iter iou: 0.336, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.665 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1223] LR: 0.0010: iter loss: 0.581, iter iou: 0.339, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.665 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1224] LR: 0.0010: iter loss: 0.771, iter iou: 0.296, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.666 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1225] LR: 0.0010: iter loss: 0.595, iter iou: 0.310, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.663 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1226] LR: 0.0010: iter loss: 0.679, iter iou: 0.372, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.656 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1227] LR: 0.0010: iter loss: 0.592, iter iou: 0.324, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.644 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1228] LR: 0.0010: iter loss: 0.561, iter iou: 0.315, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.677 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1229] LR: 0.0010: iter loss: 0.674, iter iou: 0.420, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.663 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1230] LR: 0.0010: iter loss: 0.652, iter iou: 0.331, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.673 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1231] LR: 0.0010: iter loss: 0.772, iter iou: 0.284, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.672 s
# torch.Size([786432, 8])
# torch.Size([786432])
# [Epoch-1 Iter-1232] LR: 0.0010: iter loss: 0.735, iter iou: 0.326, epoch loss: 0.676, epoch iou: 0.303,  time cost: 2.666 s
# torch.Size([786432, 8])
# torch.Size([786432])

# %%
torch.save(net.state_dict(), "result_siren.pt")

# %%
torch.save(net.state_dict(), 
                    pjoin(cfg.WEIGHTS_SAVE_ROOT, "siren_weights_ep_%d_%.3f_%.3f.pth" 
                            % (epoch, epoch_loss / epoch_size, epoch_miou / epoch_size)))
